# %%
# https://github.com/derekgreene/topic-model-tutorial/blob/master/3%20-%20Parameter%20Selection%20for%20NMF.ipynb
from pathlib import Path
import re, joblib
from itertools import combinations
import numpy as np
from sklearn import decomposition
import gensim
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
# settings for our plots later
plt.style.use("ggplot")
matplotlib.rcParams.update({"font.size": 14})

# %%
(A,terms,snippets) = joblib.load("articles-tfidf.pkl")
print("Loaded %d X %d document-term matrix" % (A.shape[0], A.shape[1]))
# Out:
# Loaded 28 X 81 document-term matrix

# %%
kmin, kmax = 4, 25

# %%
topic_models = []
# try each value of k
for k in range(kmin,kmax+1):
    print("Applying NMF for k=%d ..." % k )
    # run NMF
    model = decomposition.NMF( init="nndsvd", n_components=k ) 
    W = model.fit_transform( A )
    H = model.components_    
    # store for later
    topic_models.append( (k,W,H) )
# Out:
# Applying NMF for k=4 ...
# Applying NMF for k=5 ...
# Applying NMF for k=6 ...
# Applying NMF for k=7 ...
# Applying NMF for k=8 ...
# Applying NMF for k=9 ...
# Applying NMF for k=10 ...
# Applying NMF for k=11 ...
# Applying NMF for k=12 ...
# Applying NMF for k=13 ...
# Applying NMF for k=14 ...
# Applying NMF for k=15 ...
# Applying NMF for k=16 ...
# Applying NMF for k=17 ...
# Applying NMF for k=18 ...
# Applying NMF for k=19 ...
# Applying NMF for k=20 ...
# Applying NMF for k=21 ...
# Applying NMF for k=22 ...
# Applying NMF for k=23 ...
# Applying NMF for k=24 ...
# Applying NMF for k=25 ...

# %%
in_path = Path("data") / "articles.txt"
raw_documents = []
with open(in_path, "r", encoding="utf8") as fin:
    # each line is a document
    for line in fin.readlines():
        raw_documents.append(line.strip().lower())
print("Read %d raw text documents" % len(raw_documents))
# Out:
# Read 28 raw text documents

# %%
custom_stop_words = []
with open("stopwords.txt", "r", encoding="utf8") as fin:
    for line in fin.readlines():
        custom_stop_words.append(line.strip().lower())
# note that we need to make it hashable
print("Stopword list has %d entries" % len(custom_stop_words))
# Out:
# Stopword list has 1298 entries

# %%
class TokenGenerator:
    def __init__(self, documents, stopwords):
        self.documents = documents
        self.stopwords = stopwords
        self.tokenizer = re.compile( r"(?u)\b\w\w+\b" )

    def __iter__(self):
        print("Building Word2Vec model ...")
        for doc in self.documents:
            tokens = []
            for tok in self.tokenizer.findall( doc ):
                if tok in self.stopwords:
                    tokens.append( "<stopword>" )
                elif len(tok) >= 2:
                    tokens.append( tok )
            yield tokens

# %%
docgen = TokenGenerator(raw_documents, custom_stop_words)
# the model has 500 dimensions, the minimum document-term frequency is 20
w2v_model = gensim.models.Word2Vec(docgen, vector_size=500, min_count=5, sg=1)
# Out:
# Building Word2Vec model ...
# Building Word2Vec model ...
# Building Word2Vec model ...
# Building Word2Vec model ...
# Building Word2Vec model ...
# Building Word2Vec model ...

# %%
print("Model has %d terms" % len(w2v_model.wv.key_to_index))
# Out:
# Model has 17 terms

# %%
w2v_model.save("w2v-model.bin")

# %%
# To re-load this model, run
#w2v_model = gensim.models.Word2Vec.load("w2v-model.bin")

# %%
def calculate_coherence(w2v_model, term_rankings):
    overall_coherence = 0.0
    for topic_index in range(len(term_rankings)):
        # check each pair of terms
        pair_scores = []
        for pair in combinations( term_rankings[topic_index], 2 ):
            pair_scores.append( w2v_model.wv.similarity(pair[0], pair[1]) )
        # get the mean for all pairs in this topic
        topic_score = sum(pair_scores) / len(pair_scores)
        overall_coherence += topic_score
    # get the mean score across all topics
    return overall_coherence / len(term_rankings)

# %%
def get_descriptor( all_terms, H, topic_index, top ):
    # reverse sort the values to sort the indices
    top_indices = np.argsort( H[topic_index,:] )[::-1]
    # now get the terms corresponding to the top-ranked indices
    top_terms = []
    for term_index in top_indices[0:top]:
        top_terms.append( all_terms[term_index] )
    return top_terms

# %%
k_values = []
coherences = []
for (k,W,H) in topic_models:
    # Get all of the topic descriptors - the term_rankings, based on top 10 terms
    term_rankings = []
    for topic_index in range(k):
        term_rankings.append( get_descriptor( terms, H, topic_index, 10 ) )
    # Now calculate the coherence based on our Word2vec model
    k_values.append( k )
    coherences.append( calculate_coherence( w2v_model, term_rankings ) )
    print("K=%02d: Coherence=%.4f" % ( k, coherences[-1] ) )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 10
#       8 # Now calculate the coherence based on our Word2vec model
#       9 k_values.append( k )
# ---> 10 coherences.append( calculate_coherence( w2v_model, term_rankings ) )
#      11 print("K=%02d: Coherence=%.4f" % ( k, coherences[-1] ) )
#
# Cell In[18], line 7, in calculate_coherence(w2v_model, term_rankings)
#       5 pair_scores = []
#       6 for pair in combinations( term_rankings[topic_index], 2 ):
# ----> 7     pair_scores.append( w2v_model.wv.similarity(pair[0], pair[1]) )
#       8 # get the mean for all pairs in this topic
#       9 topic_score = sum(pair_scores) / len(pair_scores)
#
# File ~\anaconda3\lib\site-packages\gensim\models\keyedvectors.py:1234, in KeyedVectors.similarity(self, w1, w2)
#    1218 def similarity(self, w1, w2):
#    1219     """Compute cosine similarity between two keys.
#    1220
#    1221     Parameters
#    (...)
#    1232
#    1233     """
# -> 1234     return dot(matutils.unitvec(self[w1]), matutils.unitvec(self[w2]))
#
# File ~\anaconda3\lib\site-packages\gensim\models\keyedvectors.py:403, in KeyedVectors.__getitem__(self, key_or_keys)
#     389 """Get vector representation of `key_or_keys`.
#     390
#     391 Parameters
#    (...)
#     400
#     401 """
#     402 if isinstance(key_or_keys, _KEY_TYPES):
# --> 403     return self.get_vector(key_or_keys)
#     405 return vstack([self.get_vector(key) for key in key_or_keys])
#
# File ~\anaconda3\lib\site-packages\gensim\models\keyedvectors.py:446, in KeyedVectors.get_vector(self, key, norm)
#     422 def get_vector(self, key, norm=False):
#     423     """Get the key's vector, as a 1D numpy array.
#     424
#     425     Parameters
#    (...)
#     444
#     445     """
# --> 446     index = self.get_index(key)
#     447     if norm:
#     448         self.fill_norms()
#
# File ~\anaconda3\lib\site-packages\gensim\models\keyedvectors.py:420, in KeyedVectors.get_index(self, key, default)
#     418     return default
#     419 else:
# --> 420     raise KeyError(f"Key '{key}' not present")
#
# KeyError: "Key 'literature' not present"

# %%
fig = plt.figure(figsize=(13,7))
# create the line plot
ax = plt.plot( k_values, coherences )
plt.xticks(k_values)
plt.xlabel("Number of Topics")
plt.ylabel("Mean Coherence")
# add the points
plt.scatter(k_values, coherences, s=120)
# find and annotate the maximum point on the plot
ymax = max(coherences)
xpos = coherences.index(ymax)
best_k = k_values[xpos]
plt.annotate("k=%d" % best_k, xy=(best_k, ymax), xytext=(best_k, ymax), textcoords="offset points", fontsize=16)
# show the plot
plt.show()

# %%
k = best_k
# get the model that we generated earlier.
W = topic_models[k-kmin][1]
H = topic_models[k-kmin][2]

# %%
import os
if os.path.exists('Results/07_Topics.txt'):
    os.remove('Results/07_Topics.txt')

for topic_index in range(k):
    descriptor = get_descriptor(terms, H, topic_index, 5)
    str_descriptor = ", ".join(descriptor)
    #print("Topic %02d: %s" % (topic_index+1, str_descriptor) )
    print(f'Topic %02d: %s' % (topic_index+1, str_descriptor), file=open('Results/Topics.txt', 'a')) # a

# %%
from statistics import mean
import statistics

def plot_top_term_weights(terms, H, topic_index, top):
    # get the top terms and their weights
    top_indices = np.argsort(H[topic_index,:])[::-1]
    top_terms = []
    top_weights = []
    for term_index in top_indices[0:top]:
        top_terms.append(terms[term_index])
        top_weights.append(H[topic_index,term_index])
    # note we reverse the ordering for the plot
    top_terms.reverse()
    top_weights.reverse()
    print('Topic_' + str(topic_index) + ', Top-Term Weight: ' + str(top_weights[14]))
    # create the plot
    """
    fig = plt.figure(figsize=(13,8))
    # add the horizontal bar chart
    ypos = np.arange(top)
    ax = plt.barh(ypos, top_weights, align="center", color="green",tick_label=top_terms)
    plt.xlabel("Term Weight",fontsize=14)
    plt.tight_layout()
    # plt.show()
    plt.savefig('Results/Topic_' + str(topic_index) + '_plot_topic_bars.png', dpi=300, bbox_inches='tight', format="PNG")
    """

# %%
indx = 0
while indx < k:
    plot_top_term_weights(terms, H, indx, 15) # Topic (X-1)
    indx = indx + 1

#plot_top_term_weights(terms, H, 5, 15) # Topic (X-1)
# Out:
# Topic_0, Top-Term Weight: 3.4500244298450102
# Topic_1, Top-Term Weight: 2.1100071785506724
# Topic_2, Top-Term Weight: 2.0621179670223015
# Topic_3, Top-Term Weight: 2.285535277553776
# Topic_4, Top-Term Weight: 2.1182939095169937
# Topic_5, Top-Term Weight: 2.322599582642061
# Topic_6, Top-Term Weight: 1.9364751564344116
# Topic_7, Top-Term Weight: 1.7415870693327107
# Topic_8, Top-Term Weight: 2.1594614773846823
# Topic_9, Top-Term Weight: 1.620592436438089
# Topic_10, Top-Term Weight: 1.8632808982335731
# Topic_11, Top-Term Weight: 2.40454739136508
# Topic_12, Top-Term Weight: 2.171928969724627
# Topic_13, Top-Term Weight: 1.869269535017695
# Topic_14, Top-Term Weight: 2.7951926343958933
# Topic_15, Top-Term Weight: 1.5897466730583003
# Topic_16, Top-Term Weight: 1.8809459884037378
# Topic_17, Top-Term Weight: 1.5753808557094988
# Topic_18, Top-Term Weight: 1.895969721761014
# Topic_19, Top-Term Weight: 1.318903771648984
# Topic_20, Top-Term Weight: 1.8224617200193134
# Topic_21, Top-Term Weight: 1.3957698579690405
# Topic_22, Top-Term Weight: 2.1960919093653293
# Topic_23, Top-Term Weight: 2.1372127089176276
# Topic_24, Top-Term Weight: 1.6586572070340841
# Topic_25, Top-Term Weight: 2.314869071180262
# Topic_26, Top-Term Weight: 2.1337697391090082
# Topic_27, Top-Term Weight: 1.9700474294842267
# Topic_28, Top-Term Weight: 1.5309343871668424
# Topic_29, Top-Term Weight: 1.4146652792276497
# Topic_30, Top-Term Weight: 2.46702602402293
# Topic_31, Top-Term Weight: 1.414084140008398
# Topic_32, Top-Term Weight: 1.8138390472028827
# Topic_33, Top-Term Weight: 1.0001639620016283
# Topic_34, Top-Term Weight: 2.1402048383721066
# Topic_35, Top-Term Weight: 1.0948560204190865
# Topic_36, Top-Term Weight: 1.2636950784419634
# Topic_37, Top-Term Weight: 1.9915418559090425

# %%
def get_top_snippets(all_snippets, W, topic_index, top):
    # reverse sort the values to sort the indices
    top_indices = np.argsort( W[:,topic_index] )[::-1]
    print(top_indices)
    # now get the snippets corresponding to the top-ranked indices
    top_snippets = []
    for doc_index in top_indices[0:top]:
        top_snippets.append(all_snippets[doc_index])
    return top_snippets

# %%
import pandas as pd

indx = 0
while indx < k:
    topic_snippets = get_top_snippets(snippets, W, indx, 25)
    data = []
    for i, snippet in enumerate(topic_snippets):
        # print("%02d. %s" % ((i+1), snippet ))
        titleSnip = str(snippet)
        title = titleSnip.split(',"') # [0];
        print(title[0])
        data.append({'Title': title[0]})
    df = pd.DataFrame(data, columns=['Title'])
    # Saving first group of data to a single csv file
    df.to_csv('Results/Topic_' + str(indx) + '_paper_most_related.csv')
    indx = indx + 1
# Out:
# [ 43 119  22   1  24  94 155  98 111  29 143   8  77 112  32  14   6  90
#   78  86 164  47 162 116  11  33 138 152  15  37 141  27  95 125  73 168
#   97 167  21 124   4  57  96 150  13 136  18 147  23  54  49  72 154  64
#  140 126  65  20 156  85  38 128  89 108 110 142  75  40  34 122 161 151
#   51  67  12  19 133 103   7 132 137  30   5  66 129 131 170 120  63  93
#   25  76 145 158  58  26 104 121  61 127 146  55  36   9 123   3 148  68
#  135 114  80  81  31 118 117 115 130 134  28  83 139 144  17  35 149 153
#  157  10 159 160 163 165   2 166  16  41 113  71  62 100  99  92  69  70
#   91  59  88  74  87 169  84  79  60 101  39  46 109  82  42 107  44  45
#  106  56  48 105  50  52  53 102   0]
# Bridging the model-to-code abstraction gap with fuzzy logic in model-based regression test selection
# ResyDuo: Combining Data Models and CF-Based Recommender Systems to Develop Arduino Projects
# Adaptive Reward Computation in Reinforcement Learning-Based Continuous Integration Testing
# A Framework for Continuous Regression and Integration Testing in IoT Systems Based on Deep Learning
# Agile Generator-Based GUI Modeling for Information Systems
# Model-based Continuous Deployment of SIS,,
# Towards Continuous Modelling to Enable DevOps: A Preliminary Study with Practitioners
# Model-based product line evolution: An incremental growing by extension
# openCAESAR: Balancing Agility and Rigor in Model-Based Systems Engineering
# Architectural runtime models for integrating runtime observations and component-based models
# The Digital Twin as a Common Knowledge Base in DevOps to Support Continuous System Evolution
# A model-driven approach to continuous practices for modern cloud-based web applications
# Impediments to Introducing Continuous Integration for Model-Based Development in Industry
# Pattern-based Modelling, Integration, and Deployment of Microservice Architectures
# Artshop: A continuous integration and quality assessment framework for model-based software artifact
# A tag-based recommender system for regression test case prioritization
# A model-driven approach for continuous performance engineering in microservice-based systems
# Machine Learning Regression Techniques for Test Case Prioritization in Continuous Integration Enviro
# Improving Component Based Software Integration Testing Using Data Mining Technique
# Learning by sampling: learning behavioral family models from software product lines
# TwinOps - DevOps meets model-based engineering and digital twins for the engineering of CPS
# Consistency management in industrial continuous model-based development settings: a reality check
# Towards Specification Completion for Systems with Emergent Behavior based on DevOps
# Realization of a model-based DevOps process for industrial safety critical cyber physical systems
# A model-driven workflow for distributed microservice development
# [ 20  21 138  86 118 146  81  31 136   4 113 110 170  12 104 120  85 103
#  126  22  90  57  80  68  35   0  87  54  18  28  91 129  72  46 109   1
#   56  49  27   2 168   3 149  66 139   9 121  50  75  71  19 165  62 134
#  100  64  17 157  65 161  98  23 164  51 153 119 162  69  76 112 148 156
#  106  83 124  79 154  67  32 127  60  88  45 133   5  38  78  95 142  42
#  150   6 147  33  34 135  14  36  37  30 151  39  40  41  43   7   8  29
#  166  15  16 167 145 144 143  11  44  13 140  24  25  26 155  10 137 141
#  105  47  48 114 163  82  84 169 159  89 111  92  93  94  96  97 160  99
#  108 101 102 107  77 152 115  59 132 131 130  53 128  55 125  58  61  74
#   63 123 122 158  70 117 116  73  52]
# Adaptive behavioral model learning for software product lines
# Adaptive Learning for Learn-Based Regression Testing,Regression testing is an important activity to
# Testing self-healing cyber-physical systems under uncertainty with reinforcement learning: an empiri
# Learning by sampling: learning behavioral family models from software product lines
# Reinforcement learning for automatic test case prioritization and selection in continuous integratio
# The next evolution of MDE: a seamless integration of machine learning into domain modeling
# Improving model repair through experience sharing
# Artifact and reference models for generative machine learning frameworks and build systems
# Test Case Prioritization using Transfer Learning in Continuous Integration Environments
# A learning-based framework for engineering feature-oriented self-adaptive software systems
# Personalized and automatic model repairing using reinforcement learning
# On the engineering of ai-powered systems
# When DevOps meets meta-learning: A portfolio to rule them all
# A Modular and Composable Approach to Develop Trusted Artificial Intelligence
# Modeling deep reinforcement learning based architectures for cyber-physical systems
# RLOps: Development Life-Cycle of Reinforcement Learning Aided Open RAN
# Interactive Learning Engineering Concepts in AutomationML
# Modeling and Training of Neural Processing Systems
# SliceOps: Explainable MLOps for Streamlined Automation-Native 6G Networks
# Adaptive Reward Computation in Reinforcement Learning-Based Continuous Integration Testing
# Machine Learning Regression Techniques for Test Case Prioritization in Continuous Integration Enviro
# Cost-effective learning-based strategies for test case prioritization in continuous integration of h
# Improving la redoute's CI/CD pipeline and devops processes by applying machine learning techniques
# EMMM: A Unified Meta-Model for Tracking Machine Learning Experiments
# Automated Classification of Metamodel Repositories: A Machine Learning Approach
# [ 15 141  28  14   1 137 139 140 167  87  48  16 149   3  33  21  22 138
#   78 118   5 125 132 124 168 136  90 120 121 102  37 156  75  43  10  18
#   88  57 134  20 100  83   7  65 127  79 163 151  50 155 142  93  56 162
#  135  51 165  69  80  76 161  70  12  74  25  46  35  95  54  38  97  29
#   96 157  52 126  19  49  53  55  58  47  59 170  45  61   2   4   6   8
#    9  11  13  17  23  24  26  44  27  30  31  32  34  36  39  40  41  42
#   60  85  62 112 114 115 116 117 119 122 123 128 129 130 131 133 143 144
#  145 146 147 148 150 152 153 154 158 159 160 164 166 113 111  63 110  64
#   66  67  68  71  72  73  77  81  82  84 169  86  89  91  92  94  98  99
#  101 103 104 105 106 107 108 109   0]
# A testing frameworks for mobile embedded systems using MDA
# TestIt: An Open-Source Scalable Long-Term Autonomy Testing Toolkit for ROS,This paper presents an op
# AppFlow: Using machine learning to synthesize robust, reusable UI tests
# A tag-based recommender system for regression test case prioritization
# A Framework for Continuous Regression and Integration Testing in IoT Systems Based on Deep Learning
# Testing robot controllers using constraint programming and continuous integration
# Testing self-healing cyber-physical systems under uncertainty: a fragility-oriented approach
# Testing uncertainty of cyber-physical systems in IoT cloud infrastructures: Combining model-driven e
# Using Metamodels to Improve Model-Based Testing of Service Orchestrations
# Learning-to-rank vs ranking-to-learn: Strategies for regression testing in continuous integration
# Consistency reflection for automatic update of testing environment
# A Unified test framework for continuous integration testing of SOA solutions
# Towards a Domain-Specific Language for Provisioning Multiple Cloud Testing Environments for Mobile A
# A learning algorithm for optimizing continuous integration development and testing practice
# Arttest - A New Test Environment for Model-Based Software Development
# Adaptive Learning for Learn-Based Regression Testing,Regression testing is an important activity to
# Adaptive Reward Computation in Reinforcement Learning-Based Continuous Integration Testing
# Testing self-healing cyber-physical systems under uncertainty with reinforcement learning: an empiri
# Improving Component Based Software Integration Testing Using Data Mining Technique
# Reinforcement learning for automatic test case prioritization and selection in continuous integratio
# A microservice-based framework for multi-level testing of cyber-physical systems
# Skyfire: Model-Based Testing with Cucumber
# Supporting efficient test automation using lightweight MBT
# Simulation deployment blockset for MATLAB/Simulink
# VeriDevOps: Automated Protection and Prevention to Meet Security Requirements in DevOps
# [123  44  45   7  82  93  39  26  41 140   8 149  34 131 101  96  52 126
#   76  63 152 158  84  99  54 115 117  61 148  33  70  13  69 122 127  31
#  109 168  62  80  75  98 151 124 138  51 104 118  19 125  73 147  36 108
#  162  90 111 154  14 150  50  12  16  66 114  46  74  88 113 112  49 157
#   68  53  56  48  47  57  55 170  43  21   1   2   3   4   5   6   9  10
#   11  15  17  18  20  22  42  23  24  25  27  28  29  30  59  32  35  37
#   38  40  58  85  60 144 129 130 132 133 134 135 136 137 139 141 142 143
#  145 121 146 153 155 156 159 160 161 163 164 165 166 167 128 120  64  89
#   65  67  71  72  77  78  79  81  83 169  86  87  91 119  92  94  95  97
#  100 102 103 105 106 107 110 116   0]
# Self-healing multi-cloud application modelling
# Cloud MF: Applying MDE to tame the complexity of managing multi-cloud applications
# CloudMF: Model-driven management of multi-cloud applications
# A Model-Driven Approach to Continuous Delivery of Cloud Resources
# Incremental integration of microservices in cloud applications
# Model maturity-based model service composition in cloud environments
# Automation of the incremental integration of microservices architectures
# An Infrastructure Modelling Tool for Cloud Provisioning
# Autonomic Management Framework for Cloud-Native Applications
# Testing uncertainty of cyber-physical systems in IoT cloud infrastructures: Combining model-driven e
# A model-driven approach to continuous practices for modern cloud-based web applications
# Towards a Domain-Specific Language for Provisioning Multiple Cloud Testing Environments for Mobile A
# Auto-generation of domain-specific systems: Cloud-hosted devops for business
# Streamlining DevOps automation for Cloud applications using TOSCA as standardized metamodel
# Model-driven orchestration for cloud resources
# Model-based fleet deployment in the IoT–edge–cloud continuum
# Continuous deployment of trustworthy smart IoT systems
# SliceOps: Explainable MLOps for Streamlined Automation-Native 6G Networks
# Identification of microservices from monolithic applications through topic modelling
# DICE: Quality-driven development of data-intensive cloud applications
# Towards Blended Modeling and Simulation of DevOps Processes: the Keptn Case Study
# Towards model-based continuous deployment of secure IoT systems
# Infrastructure as runtime models: Towards Model-Driven resource management
# Model-Driven continuous deployment for quality devops
# Continuous learning of HPC infrastructure models using big data analytics and in-memory processing t
# [ 89 153  62 101 155 159 105  69  10 166 156  60 131  95  99 164  34 152
#   80 160 147 162   7 170 168 150  97  61 116  26  17  96 143 158  92   9
#   76  45  70  58 132 127  11 163   5  83 102  31  25  66  65 149  36 120
#    8  72  77 134  47 129 130 139  13  20 167 148 126 151 142  57  51  46
#   56  48  55  43   1  54  53  49  52  50  44  35  42  28  12  14  15  16
#   18  19  21  22  23  59  27  29  41  30  32  33   4   6   3  37   2  38
#   39  40  24  85  63 133 113 114 115 117 118 119 121 122 123 124 125 128
#  135 111 136 137 138 140 141 144 145 146 154 157 161 165 112 110  64  86
#   67  68  71  73  74  75  78  79  81  82  84 169  87 109  88  90  91  93
#   94  98 100 103 104 106 107 108   0]
# Machine learning based predictive modeling to effectively implement DevOps practices in software org
# Towards Continuous Consistency Checking of DevOps Artefacts
# DevOpsML: Towards modeling DevOps processes and platforms
# Model-driven orchestration for cloud resources
# Towards Continuous Modelling to Enable DevOps: A Preliminary Study with Practitioners
# Towards Modeling Framework for DevOps: Requirements Derived from Industry Use Case
# Modeling devOps deployment choices using process architecture design dimensions
# Enact: Development, operation, and quality assurance of trustworthy smart iot systems
# A model-driven engineering framework to support the functional safety process
# Using DevOps toolchains in Agile model-driven engineering
# Towards Digital Twin-enabled DevOps for CPS providing Architecture-Based Service Adaptation & Verifi
# DevOps and Safety? SafeOps! Towards Ensuring Safety in Feature-Driven Development with Frequent Rele
# Streamlining DevOps automation for Cloud applications using TOSCA as standardized metamodel
# Model-Based DevOps: Foundations and Challenges
# Model-Driven continuous deployment for quality devops
# TwinOps - DevOps meets model-based engineering and digital twins for the engineering of CPS
# Auto-generation of domain-specific systems: Cloud-hosted devops for business
# Towards Blended Modeling and Simulation of DevOps Processes: the Keptn Case Study
# Improving la redoute's CI/CD pipeline and devops processes by applying machine learning techniques
# Towards Modelling Acceptance Tests as a Support for Software Measurement
# The systems engineering DevOps lemniscate and model-based system operations
# Towards Specification Completion for Systems with Emergent Behavior based on DevOps
# A Model-Driven Approach to Continuous Delivery of Cloud Resources
# When DevOps meets meta-learning: A portfolio to rule them all
# VeriDevOps: Automated Protection and Prevention to Meet Security Requirements in DevOps
# [169  65  51   2  66  85  56 157  54  63 114 136  70  17   0  79 145   9
#  100  35 119 120 129 170  92  71 128  78 103  72  48  24 152 127 118  42
#  150   6  30 161  31 146  46  32  25  38  68  88  80  22   1 134  11  87
#  155 151  74  76 108  37  19 135   7  67 154 116 109  90  12 121 140  33
#  106  83 167 160 101  34 112  45  61 138   3 168 139  36 153 148 142  39
#   40  41 137  43  44 156  47 141  29  13  21  14  15  10  16 149  18   8
#   20 147   4  49  23 144 143  26  27   5  28 115  57  50  96  84 159  86
#  123 122  89  91  93  94  95  97 166  98  99 117 102 104 105 107 110 111
#  113  82  81 124 125  52  53 165  55 164 158  58  59  60  62 163  64 162
#  133 132  69 131 130  73  75 126  77]
# Verifying big data topologies by-design: a semi-automated approach
# DQSOps: Data Quality Scoring Operations Framework for Data-Driven Applications
# Continuous architecting of stream-based systems
# A Hitchhiker's Guide to Model-Driven Engineering for Data-Centric Systems,The models and data framew
# Dynamic data management for continuous retraining
# Interactive Learning Engineering Concepts in AutomationML
# Convolutional neural networks for enhanced classification mechanisms of metamodels
# Towards Integrating Data-Driven Requirements Engineering into the Software Development Process: A Vi
# Continuous learning of HPC infrastructure models using big data analytics and in-memory processing t
# DICE: Quality-driven development of data-intensive cloud applications
# Pinset: A DSL for extracting datasets from models for data mining-based quality analysis
# Test Case Prioritization using Transfer Learning in Continuous Integration Environments
# Evaluation of Graphical Modeling of CI/CD Workflows with Rig
# ACCORDANT: A domain specific-model and DevOps approach for big data analytics architectures
# A Data Quality-Driven View of MLOps
# Improving invariant mining via static analysis
# The Interoperability Challenge: Building a Model-Driven Digital Thread Platform for CPS
# A Model-Driven Architectural Design Method for Big Data Analytics Applications
# Model-driven ml-ops for intelligent enterprise applications: vision, approaches and challenges
# Automated Classification of Metamodel Repositories: A Machine Learning Approach
# ResyDuo: Combining Data Models and CF-Based Recommender Systems to Develop Arduino Projects
# RLOps: Development Life-Cycle of Reinforcement Learning Aided Open RAN
# Software Engineering for Machine Learning: A Case Study
# When DevOps meets meta-learning: A portfolio to rule them all
# Measuring performance quality scenarios in big data analytics applications: A DevOps and domain-spec
# [133 102 128  94 124 158  52 148  96 127  97  99 112  92 107   6 108   9
#   17  67 131   8 120  39  40  82  51  70  45  60 123  44 150  34 159 160
#   26  42 100   5 156 140 105  89 149  79  33 125  28 151 126 137 101  95
#   12 163 142 118  21  75 109  18 168  16 104 161  68  19 122 154 114  46
#   66  56  14 153  41  55  53  57  50  43  49  48  47  54 170  38  37   1
#    2   3   4   7  10  11  13  15  20  22  23  24  25  58  29  30  31  32
#   35  36  27  85  59 141 116 117 119 121 129 130 132 134 135 136 138 139
#  143 113 144 145 146 147 152 155 157 162 164 165 166 167 115 111  61  80
#   62  63  64  65  69  71  72  73  74  76  77  78  81 110  83  84 169  86
#   87  88  90  91  93  98 103 106   0]
# Supporting micro-services deployment in a safer way: A static analysis and automated rewriting appro
# Modeling and automated execution of application deployment tests
# Smart Infrastructures: Artificial Intelligence-Enabled Lifecycle Automation
# Model-based Continuous Deployment of SIS,,
# Simulation deployment blockset for MATLAB/Simulink
# Towards model-based continuous deployment of secure IoT systems
# Continuous deployment of trustworthy smart IoT systems
# TOSCA4QC: Two Modeling Styles for TOSCA to Automate the Deployment and Orchestration of Quantum Appl
# Model-based fleet deployment in the IoT–edge–cloud continuum
# SMADA-Fog: Semantic model driven approach to deployment and adaptivity in fog computing
# Model-based fleet deployment of edge computing applications
# Model-Driven continuous deployment for quality devops
# Pattern-based Modelling, Integration, and Deployment of Microservice Architectures
# Measuring performance quality scenarios in big data analytics applications: A DevOps and domain-spec
# Models@runtime for continuous design and deployment
# A model-driven approach for continuous performance engineering in microservice-based systems
# MontiThings: Model-Driven Development and Deployment of Reliable IoT Applications
# A Model-Driven Architectural Design Method for Big Data Analytics Applications
# ACCORDANT: A domain specific-model and DevOps approach for big data analytics architectures
# Dynamic Runtime Integration of New Models in Digital Twins
# Streamlining DevOps automation for Cloud applications using TOSCA as standardized metamodel
# A model-driven approach to continuous practices for modern cloud-based web applications
# RLOps: Development Life-Cycle of Reinforcement Learning Aided Open RAN
# Automation of the incremental integration of microservices architectures
# Automotive Architecture Framework: The experience of Volvo Cars
# [ 74   5 139 135 150 116 104  64  67 138 143 165  83  95 164 140 128 146
#  168 134  91 156  96 147 121  18  50  24 155 129  75 163 132  53  79  54
#   14  57 157 154 111  49 161 127 167  70  80  52  56  41  42  43  44  45
#   63  62  61  46  47  55  60  59  58  65  51  40  48 170  39  38  17  16
#   15  13  12  11  10   9   8   7   6   4   3   2   1  19  20  21  31  37
#   36  35  34  33  32  30  22  29  28  66  26  25  23  27  85  68 136 114
#  115 117 118 119 120 122 123 124 125 126 130 131 133 137  69 141 142 144
#  145 148 149 151 152 153 158 159 160 162 166 113 112 110 109  71  72  73
#   76  77  78  81  82  84 169  86  87  88  89  90  92  93  94  97  98  99
#  100 101 102 103 105 106 107 108   0]
# Hardware in the loop simulation for product driven control of a cyber-physical manufacturing system,
# A microservice-based framework for multi-level testing of cyber-physical systems
# Testing self-healing cyber-physical systems under uncertainty: a fragility-oriented approach
# Teaching agile model-driven engineering for cyber-physical systems
# Towards a Model-Based DevOps for Cyber-Physical Systems
# Realization of a model-based DevOps process for industrial safety critical cyber physical systems
# Modeling deep reinforcement learning based architectures for cyber-physical systems
# Digital Twin-Based Cyber Range for Industrial Internet of Things
# Dynamic Runtime Integration of New Models in Digital Twins
# Testing self-healing cyber-physical systems under uncertainty with reinforcement learning: an empiri
# The Digital Twin as a Common Knowledge Base in DevOps to Support Continuous System Evolution
# Use of Digital Twins and Digital Threads for Subway Infrastructure Monitoring
# Industrial requirements for supporting AI-enhanced model-driven engineering
# Model-Based DevOps: Foundations and Challenges
# TwinOps - DevOps meets model-based engineering and digital twins for the engineering of CPS
# Testing uncertainty of cyber-physical systems in IoT cloud infrastructures: Combining model-driven e
# Smart Infrastructures: Artificial Intelligence-Enabled Lifecycle Automation
# The next evolution of MDE: a seamless integration of machine learning into domain modeling
# VeriDevOps: Automated Protection and Prevention to Meet Security Requirements in DevOps
# Tailoring MLOps Techniques for Industry 5.0 Needs
# MDE for Machine Learning-Enabled Software Systems: A Case Study and Comparison of MontiAnna and ML-Q
# Towards Digital Twin-enabled DevOps for CPS providing Architecture-Based Service Adaptation & Verifi
# Model-based fleet deployment in the IoT–edge–cloud continuum
# The systems engineering DevOps lemniscate and model-based system operations
# Scaling agile mechatronics: An industrial case study
# [ 49 121 129   4  73 106  13  97  25  40  57 142  96   3  80  76  14 130
#  119  19  59  33 103 157  95  55 154  12 169  48  36 162  29  46  51   6
#   78  17  32 110  43  91  62  75  20 107 105  89 114  11  86   2 135  15
#   50 136   7  58  34 168  92 113  56 149 164 125  81  70  63 132  24  30
#   84 152  77  21  27  60   8 120  69 151 158   5  71 145 138 100 160  93
#  124 141 117  99 122   0 147  61   9  68 137  65 155 143 167 111  72  52
#   87 148  26 131  28   1  41  35  16  39  10  18  22  38  37  23  31  42
#  170  44  45 118 123 126 127 128 133 134 139 140 144 146 150 153 156 159
#  161 163 165 166 116 115 112  82  47  53  54  64  66  67  74  79  83 109
#   88  90  94  98 101 102 104 108  85]
# Constraint-based behavioral consistency of evolving software systems
# Scaling agile mechatronics: An industrial case study
# Software Engineering for Machine Learning: A Case Study
# A learning-based framework for engineering feature-oriented self-adaptive software systems
# Graphical and textual model-driven microservice development
# Modeling, validation, and continuous integration of software behaviours for embedded systems
# A process-oriented build tool for safety-critical model-based software development
# Model-based fleet deployment of edge computing applications
# An Extension of the QUAMOCO Quality Model to Specify and Evaluate Feature-Dependent Non-Functional R
# Automotive Architecture Framework: The experience of Volvo Cars
# Cost-effective learning-based strategies for test case prioritization in continuous integration of h
# The adaptation of test-driven software processes to industrial automation engineering
# Model-based fleet deployment in the IoT–edge–cloud continuum
# A learning algorithm for optimizing continuous integration development and testing practice
# Improving la redoute's CI/CD pipeline and devops processes by applying machine learning techniques
# Identification of microservices from monolithic applications through topic modelling
# A tag-based recommender system for regression test case prioritization
# Stepwise adoption of continuous delivery in model-driven engineering
# ResyDuo: Combining Data Models and CF-Based Recommender Systems to Develop Arduino Projects
# Adaptive application development and integration process for modern automotive software
# Detecting architectural issues during the continuous integration pipeline
# Arttest - A New Test Environment for Model-Based Software Development
# Modeling and Training of Neural Processing Systems
# Towards Integrating Data-Driven Requirements Engineering into the Software Development Process: A Vi
# Model-Based DevOps: Foundations and Challenges
# [109 117 122  27  83  72  25 168 157 160 107 156 105 100 159  23  60  41
#  158 106  74  24  33 134  34  42 164   5 116  63  53  62 152  70 104  31
#   26 108 123 114   8 124  75  46 149 147 110  52  99   6  37  45  48 128
#   36  11 162  71  10 163 135  35  30   2  12 166 144  51  61  59  58  57
#   50  56  49  55  47  54 170  44  18   1   3   4   7   9  13  14  15  16
#   17  19  43  20  21  22  28  29  65  32  38  39  40  64  85  66 139 119
#  120 121 125 126 127 129 130 131 132 133 136 137 138 140  67 141 142 143
#  145 146 148 150 151 153 154 155 161 165 167 118 115 113 112  68  69  73
#   76  77  78  79  80  81  82  84 169  86  87  88  89  90  91  92  93  94
#   95  96  97  98 101 102 103 111   0]
# Neural Language Models and Few Shot Learning for Systematic Requirements Processing in MDSE
# Refactoring architecture models for compliance with custom requirements
# Scenarios in the loop: Integrated requirements analysis and automotive system validation
# An MDE Method for Improving Deep Learning Dataset Requirements Engineering using Alloy and UML
# Industrial requirements for supporting AI-enhanced model-driven engineering
# Fundamental requirements of a machine learning operations platform for industrial metal additive man
# An Extension of the QUAMOCO Quality Model to Specify and Evaluate Feature-Dependent Non-Functional R
# VeriDevOps: Automated Protection and Prevention to Meet Security Requirements in DevOps
# Towards Integrating Data-Driven Requirements Engineering into the Software Development Process: A Vi
# Towards Modelling Acceptance Tests as a Support for Software Measurement
# Models@runtime for continuous design and deployment
# Towards Digital Twin-enabled DevOps for CPS providing Architecture-Based Service Adaptation & Verifi
# Modeling devOps deployment choices using process architecture design dimensions
# Model-driven ml-ops for intelligent enterprise applications: vision, approaches and challenges
# Towards Modeling Framework for DevOps: Requirements Derived from Industry Use Case
# Agent-based business process orchestration for IoT
# DevOps and Safety? SafeOps! Towards Ensuring Safety in Feature-Driven Development with Frequent Rele
# Autonomic Management Framework for Cloud-Native Applications
# Towards model-based continuous deployment of secure IoT systems
# Modeling, validation, and continuous integration of software behaviours for embedded systems
# Hardware in the loop simulation for product driven control of a cyber-physical manufacturing system,
# Agile Generator-Based GUI Modeling for Information Systems
# Arttest - A New Test Environment for Model-Based Software Development
# Tailoring MLOps Techniques for Industry 5.0 Needs
# Auto-generation of domain-specific systems: Cloud-hosted devops for business
# [151  53 103 105 148  70  93  11 159  84 161 124 152 167  73 104  58 122
#  111  62  24 146 115  56  29 130 113  91   9 108 102 127  68  27 114 106
#  150  47 154  63  86 140  25  83 131 147  89  19 101 126  16  14 128  43
#  109 110  22  78 153 149 160  66 165 162 155  36  33  20  67  55  87  45
#   79 125  57 123 120  64  60 119  97  76 158  12 136 157  46  42  75  81
#   52  50   4  40  44   2   1  41   3  35  39  38  23  48  18  17  15  13
#   26  10  28   8  30   7  31   6  32  34   5  21  37 170  85  49  51 117
#  118 121 129 132 133 134 135 137 138 139 141 142 143 144 145 156 163 164
#  166 168 116 112 107  80  54  59  61  65  69  71  72  74  77  82 100 169
#   88  90  92  94  95  96  98  99   0]
# Towards an assessment grid for intelligent modeling assistance
# Continuous Integration in Multi-view Modeling: A Model Transformation Pipeline Architecture for Prod
# Modeling and Training of Neural Processing Systems
# Modeling devOps deployment choices using process architecture design dimensions
# TOSCA4QC: Two Modeling Styles for TOSCA to Automate the Deployment and Orchestration of Quantum Appl
# Evaluation of Graphical Modeling of CI/CD Workflows with Rig
# Model maturity-based model service composition in cloud environments
# A model-driven workflow for distributed microservice development
# Towards Modeling Framework for DevOps: Requirements Derived from Industry Use Case
# Infrastructure as runtime models: Towards Model-Driven resource management
# Towards scalable model views on heterogeneous model resources
# Simulation deployment blockset for MATLAB/Simulink
# Towards Blended Modeling and Simulation of DevOps Processes: the Keptn Case Study
# Using Metamodels to Improve Model-Based Testing of Service Orchestrations
# Graphical and textual model-driven microservice development
# Modeling deep reinforcement learning based architectures for cyber-physical systems
# Deriving Microservice Code from Underspecified Domain Models Using DevOps-Enabled Modeling Languages
# Scenarios in the loop: Integrated requirements analysis and automotive system validation
# openCAESAR: Balancing Agility and Rigor in Model-Based Systems Engineering
# DevOpsML: Towards modeling DevOps processes and platforms
# Agile Generator-Based GUI Modeling for Information Systems
# The next evolution of MDE: a seamless integration of machine learning into domain modeling
# Process implications of executable domain models for microservices development
# Convolutional neural networks for enhanced classification mechanisms of metamodels
# Architectural runtime models for integrating runtime observations and component-based models
# [164  36  98 111  85 147  27  73   6 129 157 130  95 142  53  46  62  24
#  163 135  55  99  70  10 152  12  11   4   2 155  58 167 134 121  56 150
#  116  34 109  63 159  45 161  81 103  83  75 140  60 108  69 112 127  13
#   67 158 151 110  44 166 119  40 120 100  54 114  52  17 154 168  97  30
#  124 122  61  66 160  41  96 146  42 117  80  68   8   7 105 153 138 128
#   31  16 145 156 126  49   3   5  43   1  47  18  39  26  19  20  21  22
#   23  15  25  28  38  29  32  33  14  35   9  37  48 170  50 101 104 106
#  107 113 115 118 123 125 131 132 133 136 137 139 141 143 144 148 149 162
#  165 102  94  51  93  57  59  64  65  71  72  74  76  77  78  79  82  84
#  169  86  87  88  89  90  91  92   0]
# TwinOps - DevOps meets model-based engineering and digital twins for the engineering of CPS
# Automated derivation of configurations for the integration of software(+) engineering environments
# Model-based product line evolution: An incremental growing by extension
# openCAESAR: Balancing Agility and Rigor in Model-Based Systems Engineering
# Interactive Learning Engineering Concepts in AutomationML
# The systems engineering DevOps lemniscate and model-based system operations
# An MDE Method for Improving Deep Learning Dataset Requirements Engineering using Alloy and UML
# Graphical and textual model-driven microservice development
# A model-driven approach for continuous performance engineering in microservice-based systems
# Software Engineering for Machine Learning: A Case Study
# Towards Integrating Data-Driven Requirements Engineering into the Software Development Process: A Vi
# Stepwise adoption of continuous delivery in model-driven engineering
# Model-Based DevOps: Foundations and Challenges
# The adaptation of test-driven software processes to industrial automation engineering
# Continuous Integration in Multi-view Modeling: A Model Transformation Pipeline Architecture for Prod
# Cognifying Model-Driven Software Engineering
# DevOpsML: Towards modeling DevOps processes and platforms
# Agile Generator-Based GUI Modeling for Information Systems
# Towards transparent combination of model management execution strategies for low-code development pl
# Teaching agile model-driven engineering for cyber-physical systems
# Continuous Systems and Software Engineering for Industry 4.0: A disruptive view
# Model-Driven continuous deployment for quality devops
# Evaluation of Graphical Modeling of CI/CD Workflows with Rig
# A model-driven engineering framework to support the functional safety process
# Towards Blended Modeling and Simulation of DevOps Processes: the Keptn Case Study
# [ 30  50  40 117  23  76  29 156  73  16 141 105  53  19 165 125 126 144
#    5 100   9  59 103 108  58 112  11 120 115 116  93  41  17  33  92  70
#   56 155   4 139  35 135  37  98  81  34  90 138 119 109 149 101 170 113
#   60 106 114 153  89  15  52  39  82 148 158 124 137 142  67 146  51  10
#   49  62   8  47  54   7  55   6   3  57   2   1  48  12  46  20  28  32
#   27  26  25  24  22  21  36  45  18  38  14  13  42  31  43  44  61  85
#   63 147 123 127 128 129 130 131 132 133 134 136 140 143 145 150 121 151
#  152 154 157 159 160 161 162 163 164 166 167 168 122 118  64  84  65  66
#   68  69  71  72  74  75  77  78  79  80  83 169 111  86  87  88  91  94
#   95  96  97  99 102 104 107 110   0]
# Architecture violations detection and visualization in the continuous integration pipeline
# Continuous and Proactive Software Architecture Evaluation: An IoT Case
# Automotive Architecture Framework: The experience of Volvo Cars
# Refactoring architecture models for compliance with custom requirements
# Agent-based business process orchestration for IoT
# Identification of microservices from monolithic applications through topic modelling
# Architectural runtime models for integrating runtime observations and component-based models
# Towards Digital Twin-enabled DevOps for CPS providing Architecture-Based Service Adaptation & Verifi
# Graphical and textual model-driven microservice development
# A Unified test framework for continuous integration testing of SOA solutions
# TestIt: An Open-Source Scalable Long-Term Autonomy Testing Toolkit for ROS,This paper presents an op
# Modeling devOps deployment choices using process architecture design dimensions
# Continuous Integration in Multi-view Modeling: A Model Transformation Pipeline Architecture for Prod
# Adaptive application development and integration process for modern automotive software
# Use of Digital Twins and Digital Threads for Subway Infrastructure Monitoring
# Skyfire: Model-Based Testing with Cucumber
# SliceOps: Explainable MLOps for Streamlined Automation-Native 6G Networks
# The DYNABIC approach to resilience of critical infrastructures
# A microservice-based framework for multi-level testing of cyber-physical systems
# Model-driven ml-ops for intelligent enterprise applications: vision, approaches and challenges
# A Model-Driven Architectural Design Method for Big Data Analytics Applications
# Detecting architectural issues during the continuous integration pipeline
# Modeling and Training of Neural Processing Systems
# MontiThings: Model-Driven Development and Deployment of Reliable IoT Applications
# Deriving Microservice Code from Underspecified Domain Models Using DevOps-Enabled Modeling Languages
# [ 42  38 102  97 100  98  96  13 117  34  46 129 131 127  69 123  19 134
#    8 116 115 167  37  55 118  79 125  16 149  95 137  36 142  50  33  21
#  163 151 161  25 162  54  51 133 138 112  62 140  80  75 113  27  63  28
#   90  52 111 164  45 119 154 139  99  58   2   1  61  47  48  49   9   7
#    6  57   5  53   4  60  59   3  56  64  43  44  10  29  30  26  31  32
#   24  23  35  22  20  18  39  17  15  14  12  11  40  41 170  85  65 110
#  120 121 122 124 126 128 130 132 135 136 141 143 144 145 146 147 148 150
#  152 153 155 156 157 158 159 160 165 166 168 114 109  66 108  67  68  70
#   71  72  73  74  76  77  78  81  82  83  84 169  86  87  88  89  91  92
#   93  94 101 103 104 105 106 107   0]
# Autonomic pervasive applications driven by abstract specifications
# Automating performance bottleneck detection using search-based application profiling
# Modeling and automated execution of application deployment tests
# Model-based fleet deployment of edge computing applications
# Model-driven ml-ops for intelligent enterprise applications: vision, approaches and challenges
# Model-based product line evolution: An incremental growing by extension
# Model-based fleet deployment in the IoT–edge–cloud continuum
# A process-oriented build tool for safety-critical model-based software development
# Refactoring architecture models for compliance with custom requirements
# Auto-generation of domain-specific systems: Cloud-hosted devops for business
# Cognifying Model-Driven Software Engineering
# Software Engineering for Machine Learning: A Case Study
# Streamlining DevOps automation for Cloud applications using TOSCA as standardized metamodel
# SMADA-Fog: Semantic model driven approach to deployment and adaptivity in fog computing
# Enact: Development, operation, and quality assurance of trustworthy smart iot systems
# Self-healing multi-cloud application modelling
# Adaptive application development and integration process for modern automotive software
# Tailoring MLOps Techniques for Industry 5.0 Needs
# A model-driven approach to continuous practices for modern cloud-based web applications
# Realization of a model-based DevOps process for industrial safety critical cyber physical systems
# Process implications of executable domain models for microservices development
# Using Metamodels to Improve Model-Based Testing of Service Orchestrations
# Automated Regression Tests: A No-Code Approach for BPMN-based Process-Driven Applications
# Continuous Systems and Software Engineering for Industry 4.0: A disruptive view
# Reinforcement learning for automatic test case prioritization and selection in continuous integratio
# [ 11 143  47  77 115  48 120  88  19  13 106 122 125  60  33  10 162  29
#   73 163  42 166 121   7 119 111 145 135 108  49 130  80 159  89   2 124
#   18 132  52  26 113  92   0   3  24  39  96 147  69  82 142  78 167  79
#  129 158  28 150 154 160 155 103  31  32  30   5  61  83 157  81 151  12
#   98  55 105 110 134  66  16  67 100  17 168  62  59  84 164  45  14  53
#   93 137 109  15 165 148  63  68  27  35  46  57  44  43   4  41   1   9
#   38  37   8  20  21  22   6  23  36  34  25  40 170  50 136 114 116 117
#  118 123 126 127 128 131 133 138  51 139 140 141 144 146 149 152 153 156
#  161 112 107 104 102  54  56  58  64  65  70  71  72  74  75  76 169  86
#   87  90  91  94  95  97  99 101  85]
# A model-driven workflow for distributed microservice development
# The Digital Twin as a Common Knowledge Base in DevOps to Support Continuous System Evolution
# Consistency management in industrial continuous model-based development settings: a reality check
# Impediments to Introducing Continuous Integration for Model-Based Development in Industry
# Process implications of executable domain models for microservices development
# Consistency reflection for automatic update of testing environment
# RLOps: Development Life-Cycle of Reinforcement Learning Aided Open RAN
# LUV is not the answer: Continuous delivery of a model driven development platform
# Adaptive application development and integration process for modern automotive software
# A process-oriented build tool for safety-critical model-based software development
# Modeling, validation, and continuous integration of software behaviours for embedded systems
# Scenarios in the loop: Integrated requirements analysis and automotive system validation
# Skyfire: Model-Based Testing with Cucumber
# DevOps and Safety? SafeOps! Towards Ensuring Safety in Feature-Driven Development with Frequent Rele
# Arttest - A New Test Environment for Model-Based Software Development
# A model-driven engineering framework to support the functional safety process
# Towards Specification Completion for Systems with Emergent Behavior based on DevOps
# Architectural runtime models for integrating runtime observations and component-based models
# Graphical and textual model-driven microservice development
# Towards transparent combination of model management execution strategies for low-code development pl
# Autonomic pervasive applications driven by abstract specifications
# Using DevOps toolchains in Agile model-driven engineering
# Scaling agile mechatronics: An industrial case study
# A Model-Driven Approach to Continuous Delivery of Cloud Resources
# ResyDuo: Combining Data Models and CF-Based Recommender Systems to Develop Arduino Projects
# [ 59  75  37  43 163 145  24 118 115  30 108 110  58 130 127  26 106 124
#   56  14  34 121   5  87   7  11  90 149  61  73 119  19  39   3  82  91
#   25  62  46  79 167  52  60 126 157  50 162  81  74  95 158  99  51  67
#   45  54 114 139 112  16 109  49  12 138 159 100 122 125 128  57 123   2
#   80  47  48  53  55 170  44  42   1   4   6   8   9  10  13  15  17  18
#   20  21  22  23  27  28  29  63  32  33  35  36  38  40  41  31  85  64
#   65 129 131 132 133 134 135 136 137 140 141 142 143 144 146 147 148 150
#  151 152 153 154 155 156 160 161 164 165 166 168 120 117 116  88  66  68
#   69  70  71  72  76  77  78  83  84 169  86  89 113  92  93  94  96  97
#   98 101 102 103 104 105 107 111   0]
# Detecting architectural issues during the continuous integration pipeline
# Highly-optimizing and multi-target compiler for embedded system models :C++ compiler toolchain for t
# Automated Regression Tests: A No-Code Approach for BPMN-based Process-Driven Applications
# Bridging the model-to-code abstraction gap with fuzzy logic in model-based regression test selection
# Towards transparent combination of model management execution strategies for low-code development pl
# The Interoperability Challenge: Building a Model-Driven Digital Thread Platform for CPS
# Agile Generator-Based GUI Modeling for Information Systems
# Reinforcement learning for automatic test case prioritization and selection in continuous integratio
# Process implications of executable domain models for microservices development
# Architecture violations detection and visualization in the continuous integration pipeline
# MontiThings: Model-Driven Development and Deployment of Reliable IoT Applications
# On the engineering of ai-powered systems
# Deriving Microservice Code from Underspecified Domain Models Using DevOps-Enabled Modeling Languages
# Stepwise adoption of continuous delivery in model-driven engineering
# SMADA-Fog: Semantic model driven approach to deployment and adaptivity in fog computing
# An Infrastructure Modelling Tool for Cloud Provisioning
# Modeling, validation, and continuous integration of software behaviours for embedded systems
# Simulation deployment blockset for MATLAB/Simulink
# Convolutional neural networks for enhanced classification mechanisms of metamodels
# A tag-based recommender system for regression test case prioritization
# Auto-generation of domain-specific systems: Cloud-hosted devops for business
# Scaling agile mechatronics: An industrial case study
# A microservice-based framework for multi-level testing of cyber-physical systems
# Learning-to-rank vs ranking-to-learn: Strategies for regression testing in continuous integration
# A Model-Driven Approach to Continuous Delivery of Cloud Resources
# [ 32  25   0  63  65  18  99  69 114  80 107 158  92 126   9  60  59  98
#  170 162   4 127 106  14 136 168 145  93  16 122 164 137  17  37  30  78
#   62  74 151  75 121  68 156 111  90 103  29  12  79 165  23  54  19 149
#   33 144  73 142 154 155  40 140  20  21 157  45 153  38  49  52  44  51
#   56  55  53  39  36  50  46  41  42  48  43  47 130  28  35  34   1   2
#    3   5   6   7   8 148  10  11  13 147  15 146 167  22  24 166  26  27
#   58 143  31  57 161 141 113  96  97 100 101 102 104 105 133 108 109 110
#  112 115 163 116 117 118 119 120 132 123 124 125 152 131 128  95  94 134
#   91  61 139  64 129  66  67 160  70  71  72 138 150  76  77 135 159  81
#   82  83  84 169  86  87  88  89  85]
# Artshop: A continuous integration and quality assessment framework for model-based software artifact
# An Extension of the QUAMOCO Quality Model to Specify and Evaluate Feature-Dependent Non-Functional R
# A Data Quality-Driven View of MLOps
# DICE: Quality-driven development of data-intensive cloud applications
# DQSOps: Data Quality Scoring Operations Framework for Data-Driven Applications
# Active continuous quality control
# Model-Driven continuous deployment for quality devops
# Enact: Development, operation, and quality assurance of trustworthy smart iot systems
# Pinset: A DSL for extracting datasets from models for data mining-based quality analysis
# Improving la redoute's CI/CD pipeline and devops processes by applying machine learning techniques
# Models@runtime for continuous design and deployment
# Towards model-based continuous deployment of secure IoT systems
# Measuring performance quality scenarios in big data analytics applications: A DevOps and domain-spec
# SliceOps: Explainable MLOps for Streamlined Automation-Native 6G Networks
# A Model-Driven Architectural Design Method for Big Data Analytics Applications
# DevOps and Safety? SafeOps! Towards Ensuring Safety in Feature-Driven Development with Frequent Rele
# Detecting architectural issues during the continuous integration pipeline
# Model-based product line evolution: An incremental growing by extension
# When DevOps meets meta-learning: A portfolio to rule them all
# Towards Specification Completion for Systems with Emergent Behavior based on DevOps
# A learning-based framework for engineering feature-oriented self-adaptive software systems
# SMADA-Fog: Semantic model driven approach to deployment and adaptivity in fog computing
# Modeling, validation, and continuous integration of software behaviours for embedded systems
# A tag-based recommender system for regression test case prioritization
# Test Case Prioritization using Transfer Learning in Continuous Integration Environments
# [ 12 162  10  32  40  16 144  78   4 159   1  74  71   2  41  65  24 100
#  104  75 147 127 131 151  62  69 111 121 134 120 115 167  45  72  53 161
#   68  31  17   5 123  64  44  66  89  18  14  23 119 126 110  93  67  79
#  163  19  22 157  76  55 165  43  20  98  87 137  52  88 149 138 129  96
#  108  26 140 142 155   3 103  50  51  49  56  54  47  48 170  46  42   6
#    7   8   9  11  13  15  21  25  27  28  58  29  30  33  34  35  36  37
#   38  39  57  85  59 143 118 122 124 125 128 130 132 133 135 136 139 141
#  145 116 146 148 150 152 153 154 156 158 160 164 166 168 117 114  60  90
#   61  63  70  73  77  80  81  82  83  84 169  86  91 113  92  94  95  97
#   99 101 102 105 106 107 109 112   0]
# A Modular and Composable Approach to Develop Trusted Artificial Intelligence
# Towards Specification Completion for Systems with Emergent Behavior based on DevOps
# A model-driven engineering framework to support the functional safety process
# Artshop: A continuous integration and quality assessment framework for model-based software artifact
# Automotive Architecture Framework: The experience of Volvo Cars
# A Unified test framework for continuous integration testing of SOA solutions
# The DYNABIC approach to resilience of critical infrastructures
# Improving Component Based Software Integration Testing Using Data Mining Technique
# A learning-based framework for engineering feature-oriented self-adaptive software systems
# Towards Modeling Framework for DevOps: Requirements Derived from Industry Use Case
# A Framework for Continuous Regression and Integration Testing in IoT Systems Based on Deep Learning
# Hardware in the loop simulation for product driven control of a cyber-physical manufacturing system,
# FLAMA: A collaborative effort to build a new framework for the automated analysis of feature models,
# A Hitchhiker's Guide to Model-Driven Engineering for Data-Centric Systems,The models and data framew
# Autonomic Management Framework for Cloud-Native Applications
# DQSOps: Data Quality Scoring Operations Framework for Data-Driven Applications
# Agile Generator-Based GUI Modeling for Information Systems
# Model-driven ml-ops for intelligent enterprise applications: vision, approaches and challenges
# Modeling deep reinforcement learning based architectures for cyber-physical systems
# Highly-optimizing and multi-target compiler for embedded system models :C++ compiler toolchain for t
# The systems engineering DevOps lemniscate and model-based system operations
# SMADA-Fog: Semantic model driven approach to deployment and adaptivity in fog computing
# Streamlining DevOps automation for Cloud applications using TOSCA as standardized metamodel
# Towards an assessment grid for intelligent modeling assistance
# DevOpsML: Towards modeling DevOps processes and platforms
# [ 47  41 163  23  68  66  26  84 120 114  60  16 127 150 100 153  13  45
#   34  31   7 123  65  72 147 155 126 149  89  32 118 110 166  97  53 154
#   12 139 143  24 102 151 138 128  49  79 160  63  96 144  98 109 111  38
#  135  19 103 140  57  99  17 119 134  70  75 161 157 145 129  54  25  46
# ...
# Supporting micro-services deployment in a safer way: A static analysis and automated rewriting appro
# Convolutional neural networks for enhanced classification mechanisms of metamodels
# [ 35  31  68  80   0  28  46  91  72 126 129  90 146   2 170  89 120  87
#  168  54 104 134  75   9 125  50  71 136 165   4  19 100 118  85  15  64
#  157  17  66  56  27 155 147 131 121  36  37 167 135  14 163  24  22  63
#  142   7 160  52 109 152  29 139 115  77   1 111  62  11  88 144  26 166
#  132  76 116 117  30  32  33  34  48 156  45  44 114  38  39  40 164  41
#   42  43  47 106 119 145 153   3 158   5   6 130   8 151  10  12  13 124
#  150  16 149  18 148  20  21 123  23 122  25  49  53  51  93  82  83  84
#  169  86 138 137 108 159  92  94 113  95  96  97  98  99 107 101 102 103
#  133  81 161  79  78 105  55 143  57  58  59  60  61 112 127  65 141  67
#   69  70 140 162  73  74 110 154 128]
# Automated Classification of Metamodel Repositories: A Machine Learning Approach
# Artifact and reference models for generative machine learning frameworks and build systems
# EMMM: A Unified Meta-Model for Tracking Machine Learning Experiments
# Improving la redoute's CI/CD pipeline and devops processes by applying machine learning techniques
# A Data Quality-Driven View of MLOps
# AppFlow: Using machine learning to synthesize robust, reusable UI tests
# Cognifying Model-Driven Software Engineering
# MDE for Machine Learning-Enabled Software Systems: A Case Study and Comparison of MontiAnna and ML-Q
# Fundamental requirements of a machine learning operations platform for industrial metal additive man
# SliceOps: Explainable MLOps for Streamlined Automation-Native 6G Networks
# Software Engineering for Machine Learning: A Case Study
# Machine Learning Regression Techniques for Test Case Prioritization in Continuous Integration Enviro
# The next evolution of MDE: a seamless integration of machine learning into domain modeling
# A Hitchhiker's Guide to Model-Driven Engineering for Data-Centric Systems,The models and data framew
# When DevOps meets meta-learning: A portfolio to rule them all
# Machine learning based predictive modeling to effectively implement DevOps practices in software org
# RLOps: Development Life-Cycle of Reinforcement Learning Aided Open RAN
# Learning-to-rank vs ranking-to-learn: Strategies for regression testing in continuous integration
# VeriDevOps: Automated Protection and Prevention to Meet Security Requirements in DevOps
# Continuous learning of HPC infrastructure models using big data analytics and in-memory processing t
# Modeling deep reinforcement learning based architectures for cyber-physical systems
# Tailoring MLOps Techniques for Industry 5.0 Needs
# Highly-optimizing and multi-target compiler for embedded system models :C++ compiler toolchain for t
# A Model-Driven Architectural Design Method for Big Data Analytics Applications
# Skyfire: Model-Based Testing with Cucumber
# [160 170 161  87 159 150  73  10 157  90 133  57  23 137   6  59 113 116
#   39  49  82  52  42 132  60  74  89  70  69 142  26 111 100 141  31  58
#   41  50  43  66  72  54  81  36 143  12  33  68 147  63  55 158   5  53
#  155 131 108 149  67  95  15 151  14  78   3   4  11   9   1  35   2   8
#   34  61  62  27  32  64  65   7  28  22  25  56  40  38  21  20  19  44
#   45  46  47  18  48  17  16  51  30  24  37  13  29  85  71 140 122 123
#  124 125 126 127 128 129 130 134 135 136 138 139 144 120 145 146 148 152
#  153 154 156 162 163 164 165 166 167 168 121 119  75  97  76  77  79  80
#   83  84 169  86  88  91  92  93  94  96  98 118  99 101 102 103 104 105
#  106 107 109 110 112 114 115 117   0]
# Towards Modelling Acceptance Tests as a Support for Software Measurement
# When DevOps meets meta-learning: A portfolio to rule them all
# Towards scalable model views on heterogeneous model resources
# Learning-to-rank vs ranking-to-learn: Strategies for regression testing in continuous integration
# Towards Modeling Framework for DevOps: Requirements Derived from Industry Use Case
# Towards a Model-Based DevOps for Cyber-Physical Systems
# Graphical and textual model-driven microservice development
# A model-driven engineering framework to support the functional safety process
# Towards Integrating Data-Driven Requirements Engineering into the Software Development Process: A Vi
# Machine Learning Regression Techniques for Test Case Prioritization in Continuous Integration Enviro
# Supporting micro-services deployment in a safer way: A static analysis and automated rewriting appro
# Cost-effective learning-based strategies for test case prioritization in continuous integration of h
# Agent-based business process orchestration for IoT
# Testing robot controllers using constraint programming and continuous integration
# A model-driven approach for continuous performance engineering in microservice-based systems
# Detecting architectural issues during the continuous integration pipeline
# Personalized and automatic model repairing using reinforcement learning
# Realization of a model-based DevOps process for industrial safety critical cyber physical systems
# Automation of the incremental integration of microservices architectures
# Constraint-based behavioral consistency of evolving software systems
# Incremental integration of microservices in cloud applications
# Continuous deployment of trustworthy smart IoT systems
# Autonomic pervasive applications driven by abstract specifications
# Supporting efficient test automation using lightweight MBT
# DevOps and Safety? SafeOps! Towards Ensuring Safety in Feature-Driven Development with Frequent Rele
# [166 135  91 153  62 152  63  83 130 140  27 119 110  52 154  42 146  48
#  101 143 142 125  44 121 155  60 157  46  53  89 165 129 112  99  75  74
#  167  34  68  78 100  24  37   8 126   6 106  50   9 132 128 138 160  66
#  122  67  87  12 159 127  45  80  72  14  61  59  58  57  49   1  55  47
#   54  43  51  56  31  41  21   7   5  10  11  13  15   4  16  17  18   3
#   19  20   2  40  22  23  25  26  28  29  30  32  33  35  36  38  39 170
#   85  64 141 115 116 117 118 120 123 124 131 133 134 136 137 139 144  65
#  145 147 148 149 150 151 156 158 161 162 163 164 168 114 113 111 109  69
#   70  71  73  76  77  79  81  82  84 169  86  88  90  92  93  94  95  96
#   97  98 102 103 104 105 107 108   0]
# Using DevOps toolchains in Agile model-driven engineering
# Teaching agile model-driven engineering for cyber-physical systems
# MDE for Machine Learning-Enabled Software Systems: A Case Study and Comparison of MontiAnna and ML-Q
# Towards Continuous Consistency Checking of DevOps Artefacts
# DevOpsML: Towards modeling DevOps processes and platforms
# Towards Blended Modeling and Simulation of DevOps Processes: the Keptn Case Study
# DICE: Quality-driven development of data-intensive cloud applications
# Industrial requirements for supporting AI-enhanced model-driven engineering
# Stepwise adoption of continuous delivery in model-driven engineering
# Testing uncertainty of cyber-physical systems in IoT cloud infrastructures: Combining model-driven e
# An MDE Method for Improving Deep Learning Dataset Requirements Engineering using Alloy and UML
# ResyDuo: Combining Data Models and CF-Based Recommender Systems to Develop Arduino Projects
# On the engineering of ai-powered systems
# Continuous deployment of trustworthy smart IoT systems
# Towards continuous delivery for domain experts: Using MDE to integrate non-programmers into a softwa
# Autonomic pervasive applications driven by abstract specifications
# The next evolution of MDE: a seamless integration of machine learning into domain modeling
# Consistency reflection for automatic update of testing environment
# Model-driven orchestration for cloud resources
# The Digital Twin as a Common Knowledge Base in DevOps to Support Continuous System Evolution
# The adaptation of test-driven software processes to industrial automation engineering
# Skyfire: Model-Based Testing with Cucumber
# Cloud MF: Applying MDE to tame the complexity of managing multi-cloud applications
# Scaling agile mechatronics: An industrial case study
# Towards Continuous Modelling to Enable DevOps: A Preliminary Study with Practitioners
# [ 64  55 134  83 137 142 116 125  47  77  72 121  74  51 166  22 112   8
#  156 118 169  18 159 136 160 117  85  95   5 149 143   3  40   6  10  37
#  122 103 145  89  79  80  14 108 140  65 147  29  75  56 133  54 126  36
#   38  23  90  62  50  48  59  49  61  60  52  53  57  46  63  58  32  45
#   44   1   2   4   7   9  11  12  13  15  16  17  19  20  21  24  25  26
#   27  28  30  31  67  33  34  35  39  41  42  43  66 170  68 148 123 124
#  127 128 129 130 131 132 135 138 139 141 144 146 150 119 151 152 153 154
#  155 157 158 161 162 163 164 165 167 168 120 115  69  94  70  71  73  76
#   78  81  82  84  86  87  88  91  92  93  96 114  97  98  99 100 101 102
#  104 105 106 107 109 110 111 113   0]
# Digital Twin-Based Cyber Range for Industrial Internet of Things
# Continuous Systems and Software Engineering for Industry 4.0: A disruptive view
# Tailoring MLOps Techniques for Industry 5.0 Needs
# Industrial requirements for supporting AI-enhanced model-driven engineering
# Testing robot controllers using constraint programming and continuous integration
# The adaptation of test-driven software processes to industrial automation engineering
# Realization of a model-based DevOps process for industrial safety critical cyber physical systems
# Skyfire: Model-Based Testing with Cucumber
# Consistency management in industrial continuous model-based development settings: a reality check
# Impediments to Introducing Continuous Integration for Model-Based Development in Industry
# Fundamental requirements of a machine learning operations platform for industrial metal additive man
# Scaling agile mechatronics: An industrial case study
# Hardware in the loop simulation for product driven control of a cyber-physical manufacturing system,
# Continuous architecting of stream-based systems
# Using DevOps toolchains in Agile model-driven engineering
# Adaptive Reward Computation in Reinforcement Learning-Based Continuous Integration Testing
# Pattern-based Modelling, Integration, and Deployment of Microservice Architectures
# A model-driven approach to continuous practices for modern cloud-based web applications
# Towards Digital Twin-enabled DevOps for CPS providing Architecture-Based Service Adaptation & Verifi
# Reinforcement learning for automatic test case prioritization and selection in continuous integratio
# Verifying big data topologies by-design: a semi-automated approach
# Active continuous quality control
# Towards Modeling Framework for DevOps: Requirements Derived from Industry Use Case
# Test Case Prioritization using Transfer Learning in Continuous Integration Environments
# Towards Modelling Acceptance Tests as a Support for Software Measurement
# [ 23  19  37  13 105 130   5  88  79  76 115  18 137  10 142  48 157 167
#    0  46 159 116 168 164  87 129 110  51 114  81 102  59  98   7 121  66
#   34 132   9  74 170 152  36 106  72  93  71 134 169 124  85 162  20  54
#   62 153 136  61  31 131 120  30 117  64  15 109  58  78  17  83  27  12
#   50  75  32 103  14  68 140  40 144 154 155 148 126 141  80 156  16 138
#   38  97  28  21  22 100  24  25  26  99  29  39 125  96  33  95  35 123
#   94 101 145 160   8   1   2   3   4 166   6 165 163 104 127  11 108 161
#  107 111 139 158 112 146  41 118  63 128  65 149  67 143  69  70  86 135
#   73 113  84 147  77  82 119  60 150  49  42  43  44  45 122  47 133  92
#   89 151  52  53  91  90  56  57  55]
# Agent-based business process orchestration for IoT
# Adaptive application development and integration process for modern automotive software
# Automated Regression Tests: A No-Code Approach for BPMN-based Process-Driven Applications
# A process-oriented build tool for safety-critical model-based software development
# Modeling devOps deployment choices using process architecture design dimensions
# Stepwise adoption of continuous delivery in model-driven engineering
# A microservice-based framework for multi-level testing of cyber-physical systems
# LUV is not the answer: Continuous delivery of a model driven development platform
# Improving invariant mining via static analysis
# Identification of microservices from monolithic applications through topic modelling
# Process implications of executable domain models for microservices development
# Active continuous quality control
# Testing robot controllers using constraint programming and continuous integration
# A model-driven engineering framework to support the functional safety process
# The adaptation of test-driven software processes to industrial automation engineering
# Consistency reflection for automatic update of testing environment
# Towards Integrating Data-Driven Requirements Engineering into the Software Development Process: A Vi
# Using Metamodels to Improve Model-Based Testing of Service Orchestrations
# A Data Quality-Driven View of MLOps
# Cognifying Model-Driven Software Engineering
# Towards Modeling Framework for DevOps: Requirements Derived from Industry Use Case
# Realization of a model-based DevOps process for industrial safety critical cyber physical systems
# VeriDevOps: Automated Protection and Prevention to Meet Security Requirements in DevOps
# TwinOps - DevOps meets model-based engineering and digital twins for the engineering of CPS
# Learning-to-rank vs ranking-to-learn: Strategies for regression testing in continuous integration
# [107 111  52 147  69  12 158  49 162  55  24 142   1 150 119  40  61   4
#    6  91 104  53 106 139   5  73  43 137  10 110 103  34 146 135 116  95
#  156   2  31 102 143 113 144 138  67 159 126 145  90 124  36 168  51 161
#   83 164 128  74 140 122 169  15  75  18  77 136  84  21 115 133 154  19
#  121 134  85 151 165  27  14  54  72  32  63  68 141  65  50 117 157   3
#  109  79 129  26  39  11  82  70  20  60  89  42 127  46 131  29  45  38
#   17  44  28  23  22  30   7  33  37   8  16  41   9  35  13  25 170  47
#  130 101 105 108 112 114 118 120 123 125 132  48 148 149 152 153 155 160
#  163 166 167 100  99  98  97  56  57  58  59  62  64  66  71  76  78  80
#   81  86  87  88  92  93  94  96   0]
# Models@runtime for continuous design and deployment
# openCAESAR: Balancing Agility and Rigor in Model-Based Systems Engineering
# Continuous deployment of trustworthy smart IoT systems
# The systems engineering DevOps lemniscate and model-based system operations
# Enact: Development, operation, and quality assurance of trustworthy smart iot systems
# A Modular and Composable Approach to Develop Trusted Artificial Intelligence
# Towards model-based continuous deployment of secure IoT systems
# Constraint-based behavioral consistency of evolving software systems
# Towards Specification Completion for Systems with Emergent Behavior based on DevOps
# Continuous Systems and Software Engineering for Industry 4.0: A disruptive view
# Agile Generator-Based GUI Modeling for Information Systems
# The adaptation of test-driven software processes to industrial automation engineering
# A Framework for Continuous Regression and Integration Testing in IoT Systems Based on Deep Learning
# Towards a Model-Based DevOps for Cyber-Physical Systems
# ResyDuo: Combining Data Models and CF-Based Recommender Systems to Develop Arduino Projects
# Automotive Architecture Framework: The experience of Volvo Cars
# DevOps for IoT Systems: Fast and Continuous Monitoring Feedback of System Availability
# A learning-based framework for engineering feature-oriented self-adaptive software systems
# A model-driven approach for continuous performance engineering in microservice-based systems
# MDE for Machine Learning-Enabled Software Systems: A Case Study and Comparison of MontiAnna and ML-Q
# Modeling deep reinforcement learning based architectures for cyber-physical systems
# Continuous Integration in Multi-view Modeling: A Model Transformation Pipeline Architecture for Prod
# Modeling, validation, and continuous integration of software behaviours for embedded systems
# Testing self-healing cyber-physical systems under uncertainty: a fragility-oriented approach
# A microservice-based framework for multi-level testing of cyber-physical systems
